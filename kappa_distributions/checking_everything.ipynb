# %%
# %matplotlib inline
import numpy as np
import pylab as pl
import scipy.special as special
from scipy.integrate import quad

# Set plot parameters to make beautiful plots
pl.rcParams['figure.figsize']  = 12, 7.5
pl.rcParams['lines.linewidth'] = 1.5
pl.rcParams['font.family']     = 'serif'
pl.rcParams['font.weight']     = 'bold'
pl.rcParams['font.size']       = 20  
pl.rcParams['font.sans-serif'] = 'serif'
#pl.rcParams['text.usetex']     = True
pl.rcParams['axes.linewidth']  = 1.5
pl.rcParams['axes.titlesize']  = 'medium'
pl.rcParams['axes.labelsize']  = 'medium'

pl.rcParams['xtick.major.size'] = 8     
pl.rcParams['xtick.minor.size'] = 4     
pl.rcParams['xtick.major.pad']  = 8     
pl.rcParams['xtick.minor.pad']  = 8     
pl.rcParams['xtick.color']      = 'k'     
pl.rcParams['xtick.labelsize']  = 'medium'
pl.rcParams['xtick.direction']  = 'in'    

pl.rcParams['ytick.major.size'] = 8     
pl.rcParams['ytick.minor.size'] = 4     
pl.rcParams['ytick.major.pad']  = 8     
pl.rcParams['ytick.minor.pad']  = 8     
pl.rcParams['ytick.color']      = 'k'     
pl.rcParams['ytick.labelsize']  = 'medium'
pl.rcParams['ytick.direction']  = 'in'

# %%
#MJ vs angle emiss
data_us = np.loadtxt('/home/alex/c_runs/c_MJ_angle1.txt')
x_us = data_us[:, 0]
y_us = data_us[:, 1]

data_harmony = np.loadtxt('/home/alex/c_runs/harmony_MJ_vs_angle.txt')
x_h = data_harmony[:, 0]
y_h = data_harmony[:, 1]

y_fit = data_harmony[:, 2]

pl.title('MJ Emissivity vs. Observer Angle')
pl.semilogy(x_us * 180./np.pi, y_us, label='our c code')
pl.semilogy(x_h, y_h, label='harmony')
pl.semilogy(x_h, y_fit, label='eq. 72')
#pl.loglog(x_h, y_us/y_h)
pl.legend(loc='lower right')

pl.xlim([5., 90.])
# Out:
# (5.0, 90.0)

# %%
#MJ vs angle absorp
data_us = np.loadtxt('/home/alex/c_runs/c_MJ_angle_abs1.txt')
x_us = data_us[:, 0]
y_us = data_us[:, 1]

data_harmony = np.loadtxt('/home/alex/c_runs/harmony_MJ_vs_angle.txt')
x_h = data_harmony[:, 0]
y_h = data_harmony[:, 3]

pl.title('MJ Absorptivity vs Angle')
pl.semilogy(x_us * 180./np.pi, y_us, label='our c code')
pl.semilogy(x_h, y_h, label='harmony')
pl.legend(loc='lower right')

pl.xlim([5., 90.])
# Out:
# (5.0, 90.0)

# %%
#pl = 3 emissivity
data_us = np.loadtxt('/home/alex/c_runs/c_pl_I.txt')
data_harmony = np.loadtxt('/home/alex/c_runs/harmony_pl_total.txt')

pl.title('Power-Law Total Emissivity (p=3)')
pl.loglog(data_us[:, 0], data_us[:, 1], label='our c code')
pl.loglog(data_harmony[:, 0], data_harmony[:, 1], label='harmony')
pl.loglog(data_harmony[:, 0], data_harmony[:, 2], label='eq. 58')
pl.legend(loc='lower left')

# %%
#pl = 3 absorptivity
data_us_abs = np.loadtxt('/home/alex/c_runs/c_pl_abs_I.txt')
data_harmony = np.loadtxt('/home/alex/c_runs/harmony_pl_total.txt')

pl.title('Power-Law Total Absorptivity (p=3)')
pl.loglog(data_us_abs[:, 0], data_us_abs[:, 1], label='our c code')
pl.loglog(data_harmony[:, 0], data_harmony[:, 3], label='harmony')
pl.loglog(data_harmony[:, 0], data_harmony[:, 4], label='eq. 59')
pl.legend(loc='lower left')

# %%
#pl = 3 K_Q emissivity
data_us = np.loadtxt('/home/alex/c_runs/c_pl_Q.txt')
x_us = data_us[:, 0]
y_us = data_us[:, 1]

data_harmony = np.loadtxt('/home/alex/c_runs/harmony_pl_Q.txt')
x_h = data_harmony[:, 0]
y_h = data_harmony[:, 1]
y_fit = data_harmony[:, 2]

pl.title('Power-Law Polarized Emissivity (Q, p=3)')
pl.loglog(x_us, -y_us, label='our c code')
pl.loglog(x_h, -y_h, label='harmony')
pl.legend(loc='lower left')

# %%
#pl = 3 K_Q absorptivity
data_us = np.loadtxt('/home/alex/c_runs/c_pl_Q_abs.txt')
x_us = data_us[:, 0]
y_us = data_us[:, 1]

data_harmony = np.loadtxt('/home/alex/c_runs/harmony_pl_Q.txt')
x_h = data_harmony[:, 0]
y_h = data_harmony[:, 3]

pl.title('Power-Law Polarized Absorptivity (Q, p=3)')
pl.loglog(x_us, -y_us, label='our c code')
pl.loglog(x_h, -y_h, label='harmony')
pl.legend(loc='lower left')

# %%
#pl = 3 K_V
data_1 = np.loadtxt('/home/alex/c_runs/c_pl_V1.txt')
x_1 = data_1[:, 0]
y_1 = data_1[:, 1]


data_2 = np.loadtxt('/home/alex/c_runs/c_pl_V2.txt')
x_2 = data_2[:, 0]
y_2 = data_2[:, 1]


#print y_1+y_2
#data_harmony = np.loadtxt('/home/alex/c_runs/harmony_pl_V.txt')
#x_h = data_harmony[:, 0]
#y_h = data_harmony[:, 1]
#y_fit = data_harmony[:, 2]

#pl.title('Power-Law Polarized Emissivity (V, p=3)')
#pl.loglog(x_us, -y_us, label='our c code')
#pl.loglog(x_1, -(y_1+y_2), label='two parts')
pl.loglog(x_1, -y_1, label='test')
#pl.loglog(x_h, -y_h, label='harmony')
pl.legend(loc='lower left')
#print y_us
