# %%
# %matplotlib inline
import numpy as np
import pylab as pl
import scipy.special as special
from scipy.integrate import nquad
from scipy.integrate import quad
from scipy.misc import derivative

# Set plot parameters to make beautiful plots
pl.rcParams['figure.figsize']  = 12, 7.5
pl.rcParams['lines.linewidth'] = 1.5
pl.rcParams['font.family']     = 'serif'
pl.rcParams['font.weight']     = 'bold'
pl.rcParams['font.size']       = 20  
pl.rcParams['font.sans-serif'] = 'serif'
#pl.rcParams['text.usetex']     = True
pl.rcParams['axes.linewidth']  = 1.5
pl.rcParams['axes.titlesize']  = 'medium'
pl.rcParams['axes.labelsize']  = 'medium'

pl.rcParams['xtick.major.size'] = 8     
pl.rcParams['xtick.minor.size'] = 4     
pl.rcParams['xtick.major.pad']  = 8     
pl.rcParams['xtick.minor.pad']  = 8     
pl.rcParams['xtick.color']      = 'k'     
pl.rcParams['xtick.labelsize']  = 'medium'
pl.rcParams['xtick.direction']  = 'in'    

pl.rcParams['ytick.major.size'] = 8     
pl.rcParams['ytick.minor.size'] = 4     
pl.rcParams['ytick.major.pad']  = 8     
pl.rcParams['ytick.minor.pad']  = 8     
pl.rcParams['ytick.color']      = 'k'     
pl.rcParams['ytick.labelsize']  = 'medium'
pl.rcParams['ytick.direction']  = 'in'

# %%
data = np.loadtxt('/home/alex/Documents/verification/datafile.txt')

# %%
data.shape
# Out:
# (35, 4)

# %%
#THERMAL DISTRIBUTION
#plotting observer angle vs emissivity j
data2 = np.loadtxt('/home/alex/Documents/verification/c_thermal.txt')
data = np.loadtxt('/home/alex/Documents/verification/datafile.txt')


pl.xlabel("$\\theta$ (degrees)")
pl.ylabel("j$_\\nu$")
pl.plot(data2[:, 0], data2[:, 1], label='our c code')

#pl.plot(data[:, 0], data[:, 2], label='Eq. 72')
pl.plot(data[:, 0], data[:, 1], label='harmony')
#pl.title('Thermal j$_\\nu$: harmony vs Our Calculation')
pl.legend(loc='lower right')
pl.show()

# %%
#NONTHERMAL j_nu: iharmony vs our calculation 
#for gamma_min = 1, gamma_max = 1000, p = 3

data_nonthermal_iharmony = np.loadtxt('/home/alex/Documents/verification/datafile_nonthermal.txt')
data_nonthermal_ours = np.loadtxt('/home/alex/Documents/verification/c_pl.txt')

pl.xlabel("$\\log_{10}(\\nu$/$\\nu_c$)")
pl.ylabel("$\\log_{10}(j_\\nu / (n_eB)$)")
pl.loglog(data_nonthermal_ours[:, 0], (1./(n_e * 30.)) * data_nonthermal_ours[:, 1], label='our calculation')
pl.loglog(data_nonthermal_iharmony[:, 0], (1./(n_e * 100.)) * data_nonthermal_iharmony[:, 2], label='Eq. 58')
pl.loglog(data_nonthermal_iharmony[:, 0], (1./(n_e * 100.)) * data_nonthermal_iharmony[:, 1], label='harmony')
pl.xlim([1., 1.e7])
pl.ylim([1e-30, 1e-20])
pl.title('Power Law j$_\\nu$: harmony vs Our Calculation')
pl.legend(loc='lower left')

# %%
#kappa c_code vs python code:
#kappa = 3.5, cutoff = very large (similar to no cutoff)
data = np.loadtxt('/home/alex/Documents/verification/c_kappa.txt')
x = data[:, 0]
y = data[:, 1]

data1 = np.loadtxt('/home/alex/Documents/verification/p_kappa.txt')
x1 = data[:, 0]
y1 = data[:, 1]


pl.xlabel("$\\nu$/$\\nu_c$")
pl.ylabel("$j_\\nu$")
pl.loglog(x, y, label='c code')
pl.loglog(x1, y1, label='python code')
pl.legend()
